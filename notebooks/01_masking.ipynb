# %% [markdown]
# # 01. Masking
#
# Публичный notebook для генерации маскированного корпуса `COCOLOFA-RU v2`.
# Использует `Natasha` и модуль `research_baselines.masking.prepare_masked_dataset`.

# %%
# %pip install -q natasha tqdm

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[0]
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
elif (PROJECT_ROOT / "research_baselines").exists():
    pass

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

PROJECT_ROOT

# %%
from research_baselines.masking import prepare_masked_dataset

DATA_DIR = PROJECT_ROOT / "data"
INPUT_DATASET = DATA_DIR / "cocolofa_ru_v2.jsonl"
OUTPUT_DATASET = DATA_DIR / "cocolofa_ru_v2_masked.jsonl"

assert INPUT_DATASET.exists(), INPUT_DATASET

{
    "input_dataset": str(INPUT_DATASET),
    "output_dataset": str(OUTPUT_DATASET),
}

# %%
summary = prepare_masked_dataset(
    input_path=INPUT_DATASET,
    output_path=OUTPUT_DATASET,
    text_column="text_ru",
)
summary

# %% [markdown]
# ## Output
#
# - Канонический маскированный корпус: `data/cocolofa_ru_v2_masked.jsonl`
# - Сводка маскирования: `data/cocolofa_ru_v2_masked.summary.json`
